# %% [markdown]
# # Pandas Basics

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
path = 'C:\\Users\\shyam\\Desktop\\Indeed\\Python_India_Jobs.csv'
df = pd.read_csv(path, encoding="ISO-8859-1")
technology = os.path.basename(path).split('_')[0]

# %%
df.head()
# Out:
#                                             Job_Name                  Company  \
# 0  Flight Domain - Software Engineer - Data Scien...                   Boeing
# 1                          Network Engineer (Python)                  Astreya
# 2                               Sr. Python Developer  Conscience Technologies
# 3                              Python Scripting-Lead                Wipro Ltd
# 4                     Python Scripting-Administrator                Wipro Ltd
#
#         City       State                                         Apply_Link  \
# 0      Delhi       Delhi  https://www.indeed.co.in/viewjob?jk=9061ddec9e...
# 1  Hyderabad   Telangana  https://www.indeed.co.in/viewjob?jk=e16673aeab...
# 2  Hyderabad   Telangana  https://www.indeed.co.in/viewjob?jk=f8259ff0a5...
# 3  Hyderabad   Telangana  https://www.indeed.co.in/viewjob?jk=476fc64c87...
# 4  Hyderabad   Telangana  https://www.indeed.co.in/viewjob?jk=cbd7682c3a...
#
#    Posted_Date
# 0        Today
# 1  13 days ago
# 2  12 days ago
# 3        Today
# 4    1 day ago

# %%
df.shape
# Out:
# (381, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381 entries, 0 to 380
# Data columns (total 6 columns):
# Job_Name       381 non-null object
# Company        381 non-null object
# City           380 non-null object
# State          381 non-null object
# Apply_Link     381 non-null object
# Posted_Date    381 non-null object
# dtypes: object(6)
# memory usage: 9.0+ KB

# %%
df.tail()
# Out:
#                                               Job_Name     Company       City  \
# 376                          Network Engineer (Python)     Astreya  Hyderabad
# 377  Flight Domain - Software Engineer - Data Scien...      Boeing      Delhi
# 378                                    System Engineer     Verizon  Hyderabad
# 379                                Spec-Data Analytics     Verizon  Bengaluru
# 380               Sr. Member Technical - React, Python  Cdk Global  Hyderabad
#
#           State                                         Apply_Link  \
# 376   Telangana  https://www.indeed.co.in/viewjob?jk=e16673aeab...
# 377       Delhi  https://www.indeed.co.in/viewjob?jk=9061ddec9e...
# 378   Telangana  https://www.indeed.co.in/viewjob?jk=1a47f3f784...
# 379   Karnataka  https://www.indeed.co.in/viewjob?jk=66e6c15e9e...
# 380   Telangana  https://www.indeed.co.in/viewjob?jk=a1760a4cfe...
#
#      Posted_Date
# 376  13 days ago
# 377        Today
# 378  15 days ago
# 379  15 days ago
# 380    1 day ago

# %%
df['State'].value_counts()
# Out:
#  Telangana           154
#  Karnataka            53
#  Maharashtra          44
#  Delhi                35
#  Tamil Nadu           25
#  Kerala               23
#  Uttar Pradesh        14
#  Haryana               9
#  Madhya Pradesh        6
#  Andhra Pradesh        4
#  Gujarat               3
#  Rajasthan             2
#  Punjab                2
#  Chandigarh            2
#  Puducherry            1
# India                  1
#  Orissa                1
#  Chhattisgarh          1
#  Himachal Pradesh      1
# Name: State, dtype: int64

# %%
#Plotting a Pie chart of the Jobs across States
df['State'].value_counts().plot('pie', figsize = (12,12), autopct='%1.1f%%')
plt.title('Indeed Jobs by Location - {}'.format(technology), fontsize=15)
# Out:
# Text(0.5, 1.0, 'Indeed Jobs by Location - Python')

# %%
#Plotting a Bar Graph of the Jobs across States
s = df['State'].value_counts()
ax = s.plot(kind = 'bar', figsize = (12,8), color= "green")

#To show the text on top of the Bars
[ax.text(i, v, '{}'.format(v)) for i, v in enumerate(s)]

#Plot Properties
plt.title('Indeed Jobs by Location - {}'.format(technology), fontsize=15)
plt.xlabel("States", labelpad = 10, fontsize=12)
plt.xticks(fontsize=10)
plt.ylabel("Number of Jobs", labelpad = 10, fontsize=12)
plt.yticks(fontsize=10)
# Out:
# (array([  0.,  20.,  40.,  60.,  80., 100., 120., 140., 160., 180.]),
#  <a list of 10 Text yticklabel objects>)

# %%
df.tail()
# Out:
#                                               Job_Name     Company       City  \
# 376                          Network Engineer (Python)     Astreya  Hyderabad
# 377  Flight Domain - Software Engineer - Data Scien...      Boeing      Delhi
# 378                                    System Engineer     Verizon  Hyderabad
# 379                                Spec-Data Analytics     Verizon  Bengaluru
# 380               Sr. Member Technical - React, Python  Cdk Global  Hyderabad
#
#           State                                         Apply_Link  \
# 376   Telangana  https://www.indeed.co.in/viewjob?jk=e16673aeab...
# 377       Delhi  https://www.indeed.co.in/viewjob?jk=9061ddec9e...
# 378   Telangana  https://www.indeed.co.in/viewjob?jk=1a47f3f784...
# 379   Karnataka  https://www.indeed.co.in/viewjob?jk=66e6c15e9e...
# 380   Telangana  https://www.indeed.co.in/viewjob?jk=a1760a4cfe...
#
#      Posted_Date
# 376  13 days ago
# 377        Today
# 378  15 days ago
# 379  15 days ago
# 380    1 day ago
